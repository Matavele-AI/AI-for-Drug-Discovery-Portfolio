# %% [markdown]
# #Trabalho de Conclusão de Curso:Especialização em Data Science e Big Data

# %% [markdown]
# Neste projecto será desenvolvido um trabalho de conclusão de curso de especialização em data science e Big data.
# A proposta consiste no desenvolvimento de um modelo de QSAR-3D machine learning (regressão e classificação) para investigação de novos fármacos bloqueadores de "C-C chemokine receptor type 5", para o tratamento potencial de HIV. Estes dados serão colectados no Chebl Database.

# %% [markdown]
# # Chembl database
#  ChEMBL database (https://www.ebi.ac.uk/chembl/) é um banco de dados público que contém dados de bioatividade com curadoria de mais de 2.5 milhões de compostos. Esses compostos bioactivos foram selecionados cuidadosamente por especialistas da área. Ele é compilado a partir de mais de 85 mil documentos, 1.5 milhões  de ensaios e os dados abrangem 15 mil alvos terapêuticos, 6.3 mil mecanismos de ação dos fármacos,  e 2 mil células e 43 mil indicações de medicamentos e 757 tecidos biológicos. [Dados registrados em 08 de Setembro de 2022].

# %% [markdown]
# # PARTE 1: COLETA DE DADOS E MINERAÇÃO DE DADOS

# %%
# Etapas de execução do Projecto: Parte 1
## Passo 1: Instalação das biliotecas 
## Passo 2: Importação dos dados gerais dos compostos com atividade anti-HIV
## Passo 3: Seleção dos compostos bioactivos cujo alvo é C-C chemokine receptor type 5
## Passo 4: Salvando os dados de bioactividade
## Passo 5: Verificar a presença de missings 
## Passo 6: Préprocessamento dos dados
## Passo 7: Fazendo a iteração dos dados
## Passo 8: Salvar os dados pré-processados

# %% [markdown]
# # Passo 1: Instalação das biliotecas

# %%
## 1.1. Instalando a biblioteca Chebl

# !pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.7/dist-packages (0.10.8)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Requirement already satisfied: requests-cache~=0.7.0 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)

# %%
## 1.2.  Importando a biblioteca pandas
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Passo 2: Importação dos dados gerais dos compostos com atividade anti-HIV

# %%
# Pesquisa de alvo de coronavirus
alvo = new_client.target
pesquisa_alvo = alvo.search('HIV')
alvos = pd.DataFrame.from_dict(pesquisa_alvo)
alvos
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P51681', 'xref_name': None, 'xre...
# 5  [{'xref_id': 'P15822', 'xref_name': None, 'xre...
# 6  [{'xref_id': 'Q92993', 'xref_name': None, 'xre...
# 7                                                 []
# 8                                                 []
#
#                        organism  \
# 0  Human immunodeficiency virus
# 1                 HIV-1 M:B_Lai
# 2                  Homo sapiens
# 3                  Homo sapiens
# 4                  Homo sapiens
# 5                  Homo sapiens
# 6                  Homo sapiens
# 7                  Homo sapiens
# 8                  Homo sapiens
#
#                                            pref_name  score  \
# 0                                       HIV protease   20.0
# 1                                      HIV-1 M:B_Lai   14.0
# 2                        Transcription factor HIVEP2   12.0
# 3                        Ubiquitin thioesterase OTU1   12.0
# 4                      C-C chemokine receptor type 5   11.0
# 5  Human immunodeficiency virus type I enhancer-b...    9.0
# 6                     Histone acetyltransferase KAT5    9.0
# 7                    CCR5/mu opioid receptor complex    9.0
# 8                                       80S Ribosome    0.0
#
#    species_group_flag target_chembl_id  \
# 0               False    CHEMBL3638323
# 1               False     CHEMBL612775
# 2               False    CHEMBL4523214
# 3               False    CHEMBL4630833
# 4               False        CHEMBL274
# 5               False       CHEMBL2909
# 6               False       CHEMBL5750
# 7               False    CHEMBL3301384
# 8               False    CHEMBL3987582
#
#                                    target_components  \
# 0  [{'accession': 'Q9YQ30', 'component_descriptio...
# 1                                                 []
# 2  [{'accession': 'P31629', 'component_descriptio...
# 3  [{'accession': 'Q5VVQ6', 'component_descriptio...
# 4  [{'accession': 'P51681', 'component_descriptio...
# 5  [{'accession': 'P15822', 'component_descriptio...
# 6  [{'accession': 'Q92993', 'component_descriptio...
# 7  [{'accession': 'P51681', 'component_descriptio...
# 8  [{'accession': 'P08865', 'component_descriptio...
#
#                     target_type  tax_id
# 0                SINGLE PROTEIN   12721
# 1                      ORGANISM  290579
# 2                SINGLE PROTEIN    9606
# 3                SINGLE PROTEIN    9606
# 4                SINGLE PROTEIN    9606
# 5                SINGLE PROTEIN    9606
# 6                SINGLE PROTEIN    9606
# 7               PROTEIN COMPLEX    9606
# 8  PROTEIN NUCLEIC-ACID COMPLEX    9606

# %% [markdown]
# # Passo 3: Seleção dos compostos bioativos cujo alvo é "C-C chemokine receptor type 5"

# %%
## 3.1. Selecionando o alvo molecular na base (C-C chemokine receptor type 5) de dados Chambl 
alvo_selecionado = alvos.target_chembl_id[4]
alvo_selecionado
# Out:
# 'CHEMBL274'

# %% [markdown]
# Importante: aqui usaremos apenas os compostos bioativos do "alvo molecuclar C-C chemokine receptor type 5" cujos dados de atividade foram relatadas como valores de IC50 em  unidades de nM

# %%
## 3.2. Seleccionando os compostos bioativos com  dados de IC50 na unidade de nM
actividade = new_client.activity
resultado = actividade.filter(target_chembl_id=alvo_selecionado).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(resultado)
display(df)
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        75508                  []    CHEMBL654653
# 1                None        75509                  []    CHEMBL654653
# 2                None        75510                  []    CHEMBL654653
# 3                None        76739                  []    CHEMBL873385
# 4                None        77749                  []    CHEMBL654653
# ...               ...          ...                 ...             ...
# 3864             None     23301213                  []   CHEMBL4842049
# 3865   Not Determined     23301214                  []   CHEMBL4842049
# 3866             None     23301215                  []   CHEMBL4842050
# 3867             None     23301216                  []   CHEMBL4842050
# 3868   Not Determined     23301217                  []   CHEMBL4842050
#
#                                       assay_description assay_type  \
# 0     Binding affinity against C-C chemokine recepto...          B
# 1     Binding affinity against C-C chemokine recepto...          B
# 2     Binding affinity against C-C chemokine recepto...          B
# 3     Binding affinity against human CCR5 receptor s...          B
# 4     Binding affinity against C-C chemokine recepto...          B
# ...                                                 ...        ...
# 3864  Antagonist activity at CCR5 in human periphera...          F
# 3865  Antagonist activity at CCR5 in human periphera...          F
# 3866  Antagonist activity at CCR5 in human whole blo...          F
# 3867  Antagonist activity at CCR5 in human whole blo...          F
# 3868  Antagonist activity at CCR5 in human whole blo...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000219
# 1                       None                   None  BAO_0000190  BAO_0000219
# 2                       None                   None  BAO_0000190  BAO_0000219
# 3                       None                   None  BAO_0000190  BAO_0000219
# 4                       None                   None  BAO_0000190  BAO_0000219
# ...                      ...                    ...          ...          ...
# 3864                    None                   None  BAO_0000190  BAO_0000219
# 3865                    None                   None  BAO_0000190  BAO_0000219
# 3866                    None                   None  BAO_0000190  BAO_0000221
# 3867                    None                   None  BAO_0000190  BAO_0000221
# 3868                    None                   None  BAO_0000190  BAO_0000221
#
#       ... target_organism               target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 1     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 2     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 4     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# ...   ...             ...                            ...           ...
# 3864  ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3865  ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3866  ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3867  ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3868  ...    Homo sapiens  C-C chemokine receptor type 5          9606
#
#      text_value  toid  type  units    uo_units upper_value  value
# 0          None  None  IC50     nM  UO_0000065        None  335.0
# 1          None  None  IC50     nM  UO_0000065        None   28.0
# 2          None  None  IC50     nM  UO_0000065        None   10.0
# 3          None  None  IC50     nM  UO_0000065        None   35.0
# 4          None  None  IC50     nM  UO_0000065        None   15.0
# ...         ...   ...   ...    ...         ...         ...    ...
# 3864       None  None  IC50     nM  UO_0000065        None    1.1
# 3865       None  None  IC50   None        None        None   None
# 3866       None  None  IC50     nM  UO_0000065        None   34.7
# 3867       None  None  IC50     nM  UO_0000065        None    5.7
# 3868       None  None  IC50   None        None        None   None
#
# [3869 rows x 45 columns]

# %%
## Observando todas as colunas (variáveis) do dataset
df.count()
# Out:
# activity_comment              951
# activity_id                  3869
# activity_properties          3869
# assay_chembl_id              3869
# assay_description            3869
# assay_type                   3869
# assay_variant_accession         0
# assay_variant_mutation          0
# bao_endpoint                 3869
# bao_format                   3869
# bao_label                    3869
# canonical_smiles             3837
# data_validity_comment          65
# data_validity_description      65
# document_chembl_id           3869
# document_journal             2994
# document_year                2998
# ligand_efficiency            1953
# molecule_chembl_id           3869
# molecule_pref_name            911
# parent_molecule_chembl_id    3869
# pchembl_value                2728
# potential_duplicate          3869
# qudt_units                   2971
# record_id                    3869
# relation                     2929
# src_id                       3869
# standard_flag                3869
# standard_relation            2929
# standard_text_value             0
# standard_type                3869
# standard_units               2971
# standard_upper_value            0
# standard_value               2929
# target_chembl_id             3869
# target_organism              3869
# target_pref_name             3869
# target_tax_id                3869
# text_value                      0
# toid                            0
# type                         3869
# units                        2604
# uo_units                     2971
# upper_value                     0
# value                        2929
# dtype: int64

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# # Passo 4: Salvando os dados de bioatividade

# %%
df.to_csv('dados_bioactividade.csv', index=False)

# %% [markdown]
# # Passo 5: Verificar a presença de missings

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        75508                  []    CHEMBL654653
# 1                None        75509                  []    CHEMBL654653
# 2                None        75510                  []    CHEMBL654653
# 3                None        76739                  []    CHEMBL873385
# 4                None        77749                  []    CHEMBL654653
# ...               ...          ...                 ...             ...
# 3862             None     23301211                  []   CHEMBL4842048
# 3863             None     23301212                  []   CHEMBL4842049
# 3864             None     23301213                  []   CHEMBL4842049
# 3866             None     23301215                  []   CHEMBL4842050
# 3867             None     23301216                  []   CHEMBL4842050
#
#                                       assay_description assay_type  \
# 0     Binding affinity against C-C chemokine recepto...          B
# 1     Binding affinity against C-C chemokine recepto...          B
# 2     Binding affinity against C-C chemokine recepto...          B
# 3     Binding affinity against human CCR5 receptor s...          B
# 4     Binding affinity against C-C chemokine recepto...          B
# ...                                                 ...        ...
# 3862  Displacement of [125I]MIP-1beta from CCR5 in h...          B
# 3863  Antagonist activity at CCR5 in human periphera...          F
# 3864  Antagonist activity at CCR5 in human periphera...          F
# 3866  Antagonist activity at CCR5 in human whole blo...          F
# 3867  Antagonist activity at CCR5 in human whole blo...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000219
# 1                       None                   None  BAO_0000190  BAO_0000219
# 2                       None                   None  BAO_0000190  BAO_0000219
# 3                       None                   None  BAO_0000190  BAO_0000219
# 4                       None                   None  BAO_0000190  BAO_0000219
# ...                      ...                    ...          ...          ...
# 3862                    None                   None  BAO_0000190  BAO_0000219
# 3863                    None                   None  BAO_0000190  BAO_0000219
# 3864                    None                   None  BAO_0000190  BAO_0000219
# 3866                    None                   None  BAO_0000190  BAO_0000221
# 3867                    None                   None  BAO_0000190  BAO_0000221
#
#       ... target_organism               target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 1     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 2     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 4     ...    Homo sapiens  C-C chemokine receptor type 5          9606
# ...   ...             ...                            ...           ...
# 3862  ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3863  ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3864  ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3866  ...    Homo sapiens  C-C chemokine receptor type 5          9606
# 3867  ...    Homo sapiens  C-C chemokine receptor type 5          9606
#
#      text_value  toid  type  units    uo_units upper_value  value
# 0          None  None  IC50     nM  UO_0000065        None  335.0
# 1          None  None  IC50     nM  UO_0000065        None   28.0
# 2          None  None  IC50     nM  UO_0000065        None   10.0
# 3          None  None  IC50     nM  UO_0000065        None   35.0
# 4          None  None  IC50     nM  UO_0000065        None   15.0
# ...         ...   ...   ...    ...         ...         ...    ...
# 3862       None  None  IC50     nM  UO_0000065        None    3.6
# 3863       None  None  IC50     nM  UO_0000065        None    1.1
# 3864       None  None  IC50     nM  UO_0000065        None    1.1
# 3866       None  None  IC50     nM  UO_0000065        None   34.7
# 3867       None  None  IC50     nM  UO_0000065        None    5.7
#
# [2929 rows x 45 columns]

# %% [markdown]
# # Passo 6: Pré-processamento dos dados

# %%
## Atribuindo a classe dos compostos: ativo: IC50<1000 nM; inativo =IC50>10000 nM; Intermediário: IC50: 1000-100000 nM
## A Variável de interesse é sempre "standard_value"

classe_bioatividade = []
for i in df2.standard_value:
    if float(i) >= 10000:
        classe_bioatividade.append("Inativo")
    elif float(i) < 1000:
        classe_bioatividade.append("Ativo")
    else:
        classe_bioatividade.append("Intermediário")

# %% [markdown]
# # Passo 7: Realizando a iteração dos dados

# %%
# Visualizando os compostos bioactivos
df2.molecule_chembl_id
# Out:
# 0        CHEMBL105460
# 1        CHEMBL105606
# 2        CHEMBL105570
# 3         CHEMBL83338
# 4        CHEMBL325357
#             ...
# 3862    CHEMBL4594419
# 3863    CHEMBL4781426
# 3864    CHEMBL4594419
# 3866    CHEMBL4781426
# 3867    CHEMBL4594419
# Name: molecule_chembl_id, Length: 2929, dtype: object

# %%
## 7.1. Iterando os compostos bioactivos
mol_cid = []
for i in df2.molecule_chembl_id:
    mol_cid.append(i)

# %%
# Imprimindo a variavel mol_cid
mol_cid
# Out:
# ['CHEMBL105460',
#  'CHEMBL105606',
#  'CHEMBL105570',
#  'CHEMBL83338',
#  'CHEMBL325357',
#  'CHEMBL105572',
#  'CHEMBL107750',
#  'CHEMBL105659',
#  'CHEMBL107380',
#  'CHEMBL104793',
#  'CHEMBL106231',
#  'CHEMBL321539',
#  'CHEMBL322439',
#  'CHEMBL104474',
#  'CHEMBL319622',
#  'CHEMBL104867',
#  'CHEMBL104867',
#  'CHEMBL104464',
#  'CHEMBL106803',
#  'CHEMBL107380',
#  'CHEMBL320365',
#  'CHEMBL61536',
#  'CHEMBL61536',
#  'CHEMBL61536',
#  'CHEMBL61536',
#  'CHEMBL61374',
#  'CHEMBL61374',
#  'CHEMBL61374',
#  'CHEMBL61374',
#  'CHEMBL292625',
#  'CHEMBL292625',
#  'CHEMBL292625',
#  'CHEMBL59511',
#  'CHEMBL59511',
#  'CHEMBL59511',
#  'CHEMBL60711',
#  'CHEMBL60711',
#  'CHEMBL59492',
#  'CHEMBL59492',
#  'CHEMBL61465',
#  'CHEMBL556314',
#  'CHEMBL556314',
#  'CHEMBL556314',
#  'CHEMBL59602',
#  'CHEMBL59602',
#  'CHEMBL59602',
#  'CHEMBL418120',
#  'CHEMBL418120',
#  'CHEMBL58176',
#  'CHEMBL292894',
#  'CHEMBL292894',
#  'CHEMBL292894',
#  'CHEMBL58101',
#  'CHEMBL58101',
#  'CHEMBL58101',
#  'CHEMBL61828',
#  'CHEMBL61828',
#  'CHEMBL61828',
#  'CHEMBL58441',
#  'CHEMBL58441',
#  'CHEMBL58441',
#  'CHEMBL59328',
#  'CHEMBL59328',
#  'CHEMBL58004',
#  'CHEMBL58004',
#  'CHEMBL58004',
#  'CHEMBL58004',
#  'CHEMBL304931',
#  'CHEMBL58897',
#  'CHEMBL58897',
#  'CHEMBL58897',
#  'CHEMBL301454',
#  'CHEMBL301454',
#  'CHEMBL301454',
#  'CHEMBL301454',
#  'CHEMBL416512',
#  'CHEMBL60279',
#  'CHEMBL60279',
#  'CHEMBL60279',
#  'CHEMBL62152',
#  'CHEMBL62152',
#  'CHEMBL62152',
#  'CHEMBL62152',
#  'CHEMBL61424',
#  'CHEMBL61424',
#  'CHEMBL61424',
#  'CHEMBL59358',
#  'CHEMBL61466',
#  'CHEMBL61466',
#  'CHEMBL61466',
#  'CHEMBL59285',
#  'CHEMBL294271',
#  'CHEMBL294271',
#  'CHEMBL294271',
#  'CHEMBL61373',
#  'CHEMBL61373',
#  'CHEMBL61373',
#  'CHEMBL61373',
#  'CHEMBL61373',
#  'CHEMBL58109',
#  'CHEMBL58109',
#  'CHEMBL58109',
#  'CHEMBL293900',
#  'CHEMBL293900',
#  'CHEMBL293900',
#  'CHEMBL60589',
#  'CHEMBL60225',
#  'CHEMBL60225',
#  'CHEMBL60225',
#  'CHEMBL59101',
#  'CHEMBL59101',
#  'CHEMBL59101',
#  'CHEMBL433635',
#  'CHEMBL433635',
#  'CHEMBL58248',
#  'CHEMBL58248',
#  'CHEMBL58248',
#  'CHEMBL58387',
#  'CHEMBL58387',
#  'CHEMBL58387',
#  'CHEMBL311795',
#  'CHEMBL352514',
#  'CHEMBL81252',
#  'CHEMBL84268',
#  'CHEMBL82786',
#  'CHEMBL311532',
#  'CHEMBL81926',
#  'CHEMBL81719',
#  'CHEMBL2114183',
#  'CHEMBL353330',
#  'CHEMBL312945',
#  'CHEMBL368637',
#  'CHEMBL309657',
#  'CHEMBL83823',
#  'CHEMBL311248',
#  'CHEMBL353331',
#  'CHEMBL353331',
#  'CHEMBL79667',
#  'CHEMBL174304',
#  'CHEMBL311549',
#  'CHEMBL82879',
#  'CHEMBL421527',
#  'CHEMBL79930',
#  'CHEMBL172551',
#  'CHEMBL311052',
#  'CHEMBL83057',
#  'CHEMBL172371',
#  'CHEMBL82048',
#  'CHEMBL79622',
#  'CHEMBL435538',
#  'CHEMBL80043',
#  'CHEMBL432360',
#  'CHEMBL82880',
#  'CHEMBL172854',
#  'CHEMBL84029',
#  'CHEMBL313216',
#  'CHEMBL311261',
#  'CHEMBL85086',
#  'CHEMBL421342',
#  'CHEMBL81245',
#  'CHEMBL440137',
#  'CHEMBL435727',
#  'CHEMBL83335',
#  'CHEMBL430818',
#  'CHEMBL79504',
#  'CHEMBL83338',
#  'CHEMBL2114185',
#  'CHEMBL79770',
#  'CHEMBL84309',
#  'CHEMBL174457',
#  'CHEMBL84351',
#  'CHEMBL79930',
#  'CHEMBL83773',
#  'CHEMBL173095',
#  'CHEMBL310645',
#  'CHEMBL82168',
#  'CHEMBL310106',
#  'CHEMBL79907',
#  'CHEMBL432182',
#  'CHEMBL309922',
#  'CHEMBL79315',
#  'CHEMBL79530',
#  'CHEMBL83113',
#  'CHEMBL431009',
#  'CHEMBL2114184',
#  'CHEMBL445836',
#  'CHEMBL170892',
#  'CHEMBL175327',
#  'CHEMBL310369',
#  'CHEMBL309619',
#  'CHEMBL309447',
#  'CHEMBL93168',
#  'CHEMBL327241',
#  'CHEMBL328260',
#  'CHEMBL330285',
#  'CHEMBL327354',
#  'CHEMBL328373',
#  'CHEMBL93851',
#  'CHEMBL329813',
#  'CHEMBL92133',
#  'CHEMBL329107',
#  'CHEMBL327898',
#  'CHEMBL93961',
#  'CHEMBL430867',
#  'CHEMBL93691',
#  'CHEMBL96217',
#  'CHEMBL330065',
#  'CHEMBL93229',
#  'CHEMBL94179',
#  'CHEMBL93457',
#  'CHEMBL92861',
#  'CHEMBL93887',
#  'CHEMBL315159',
#  'CHEMBL327801',
#  'CHEMBL90015',
#  'CHEMBL406552',
#  'CHEMBL93277',
#  'CHEMBL329417',
#  'CHEMBL441635',
#  'CHEMBL430905',
#  'CHEMBL329382',
#  'CHEMBL329893',
#  'CHEMBL93139',
#  'CHEMBL91697',
#  'CHEMBL327392',
#  'CHEMBL327540',
#  'CHEMBL327478',
#  'CHEMBL327800',
#  'CHEMBL94032',
#  'CHEMBL93644',
#  'CHEMBL329555',
#  'CHEMBL93625',
#  'CHEMBL94182',
#  'CHEMBL327846',
#  'CHEMBL90129',
#  'CHEMBL91339',
#  'CHEMBL431852',
#  'CHEMBL316073',
#  'CHEMBL327186',
#  'CHEMBL329140',
#  'CHEMBL329131',
#  'CHEMBL328297',
#  'CHEMBL92803',
#  'CHEMBL330528',
#  'CHEMBL94031',
#  'CHEMBL414222',
#  'CHEMBL328445',
#  'CHEMBL93949',
#  'CHEMBL91793',
#  'CHEMBL96242',
#  'CHEMBL92013',
#  'CHEMBL85086',
#  'CHEMBL322817',
#  'CHEMBL120569',
#  'CHEMBL118501',
#  'CHEMBL120204',
#  'CHEMBL121321',
#  'CHEMBL331754',
#  'CHEMBL120584',
#  'CHEMBL402701',
#  'CHEMBL120419',
#  'CHEMBL118196',
#  'CHEMBL331007',
#  'CHEMBL332908',
#  'CHEMBL332458',
#  'CHEMBL324284',
#  'CHEMBL118544',
#  'CHEMBL120513',
#  'CHEMBL261935',
#  'CHEMBL176392',
#  'CHEMBL368183',
#  'CHEMBL367837',
#  'CHEMBL172761',
#  'CHEMBL174283',
#  'CHEMBL368265',
#  'CHEMBL173609',
#  'CHEMBL367863',
#  'CHEMBL173262',
#  'CHEMBL355749',
#  'CHEMBL368517',
#  'CHEMBL367421',
#  'CHEMBL369189',
#  'CHEMBL367446',
#  'CHEMBL172944',
#  'CHEMBL367787',
#  'CHEMBL172721',
#  'CHEMBL81252',
#  'CHEMBL367838',
#  'CHEMBL352981',
#  'CHEMBL170543',
#  'CHEMBL353827',
#  'CHEMBL173064',
#  'CHEMBL413058',
#  'CHEMBL102826',
#  'CHEMBL368757',
#  'CHEMBL172659',
#  'CHEMBL435724',
#  'CHEMBL367894',
#  'CHEMBL366450',
#  'CHEMBL170717',
#  'CHEMBL366536',
#  'CHEMBL172845',
#  'CHEMBL170987',
#  'CHEMBL366626',
#  'CHEMBL435709',
#  'CHEMBL435526',
#  'CHEMBL353331',
#  'CHEMBL353331',
#  'CHEMBL433980',
#  'CHEMBL366439',
#  'CHEMBL174303',
#  'CHEMBL171911',
#  'CHEMBL2112560',
#  'CHEMBL480503',
#  'CHEMBL2112553',
#  'CHEMBL511494',
#  'CHEMBL2112559',
#  'CHEMBL2112556',
#  'CHEMBL480693',
#  'CHEMBL2112555',
#  'CHEMBL471765',
#  'CHEMBL2112554',
#  'CHEMBL520755',
#  'CHEMBL513564',
#  'CHEMBL470507',
#  'CHEMBL471722',
#  'CHEMBL326487',
#  'CHEMBL2112557',
#  'CHEMBL511154',
#  'CHEMBL333619',
#  'CHEMBL471766',
#  'CHEMBL511806',
#  'CHEMBL481080',
#  'CHEMBL480504',
#  'CHEMBL2112558',
#  'CHEMBL481274',
#  'CHEMBL2112552',
#  'CHEMBL277930',
#  'CHEMBL88976',
#  'CHEMBL314077',
#  'CHEMBL91045',
#  'CHEMBL314124',
#  'CHEMBL328024',
#  'CHEMBL89167',
#  'CHEMBL89251',
#  'CHEMBL330734',
#  'CHEMBL327703',
#  'CHEMBL314551',
#  'CHEMBL329146',
#  'CHEMBL313072',
#  'CHEMBL313071',
#  'CHEMBL314342',
#  'CHEMBL89279',
#  'CHEMBL88644',
#  'CHEMBL315293',
#  'CHEMBL328025',
#  'CHEMBL315084',
#  'CHEMBL79504',
#  'CHEMBL314486',
#  'CHEMBL88319',
#  'CHEMBL86419',
#  'CHEMBL330570',
#  'CHEMBL421356',
#  'CHEMBL87167',
#  'CHEMBL88261',
#  'CHEMBL90272',
#  'CHEMBL88159',
#  'CHEMBL88344',
#  'CHEMBL89221',
#  'CHEMBL90385',
#  'CHEMBL420057',
#  'CHEMBL421168',
#  'CHEMBL315707',
#  'CHEMBL90620',
#  'CHEMBL305026',
#  'CHEMBL70124',
#  'CHEMBL330528',
#  'CHEMBL33335',
#  'CHEMBL431111',
#  'CHEMBL408438',
#  'CHEMBL284487',
#  'CHEMBL330528',
#  'CHEMBL287515',
#  'CHEMBL431111',
#  'CHEMBL284380',
#  'CHEMBL33330',
#  'CHEMBL328297',
#  'CHEMBL103813',
#  'CHEMBL319689',
#  'CHEMBL320149',
#  'CHEMBL102674',
#  'CHEMBL99909',
#  'CHEMBL322422',
#  'CHEMBL103790',
#  'CHEMBL319593',
#  'CHEMBL100336',
#  'CHEMBL100958',
#  'CHEMBL317710',
#  'CHEMBL101961',
#  'CHEMBL318210',
#  'CHEMBL323370',
#  'CHEMBL322603',
#  'CHEMBL316475',
#  'CHEMBL100596',
#  'CHEMBL322232',
#  'CHEMBL432596',
#  'CHEMBL319593',
#  'CHEMBL419895',
#  'CHEMBL102675',
#  'CHEMBL103268',
#  'CHEMBL318909',
#  'CHEMBL102826',
#  'CHEMBL99788',
#  'CHEMBL103343',
#  'CHEMBL318681',
#  'CHEMBL320386',
#  'CHEMBL322603',
#  'CHEMBL322693',
#  'CHEMBL420465',
#  'CHEMBL103782',
#  'CHEMBL20896',
#  'CHEMBL317908',
#  'CHEMBL318406',
#  'CHEMBL101333',
#  'CHEMBL425845',
#  'CHEMBL20988',
#  'CHEMBL177071',
#  'CHEMBL366400',
#  'CHEMBL177156',
#  'CHEMBL177033',
#  'CHEMBL278117',
#  'CHEMBL20598',
#  'CHEMBL176604',
#  'CHEMBL175394',
#  'CHEMBL171958',
#  'CHEMBL367416',
#  'CHEMBL367897',
#  'CHEMBL355809',
#  'CHEMBL262402',
#  'CHEMBL366868',
#  'CHEMBL278383',
#  'CHEMBL366494',
#  'CHEMBL172820',
#  'CHEMBL173583',
#  'CHEMBL176391',
#  'CHEMBL172327',
#  'CHEMBL177648',
#  'CHEMBL369659',
#  'CHEMBL369235',
#  'CHEMBL354413',
#  'CHEMBL173254',
#  'CHEMBL440554',
#  'CHEMBL176933',
#  'CHEMBL20602',
#  'CHEMBL21117',
#  'CHEMBL21167',
#  'CHEMBL172854',
#  'CHEMBL366600',
#  'CHEMBL173630',
#  'CHEMBL369278',
#  'CHEMBL172090',
#  'CHEMBL368333',
#  'CHEMBL172019',
#  'CHEMBL368000',
#  'CHEMBL172806',
#  'CHEMBL175079',
#  'CHEMBL369494',
#  'CHEMBL174214',
#  'CHEMBL21147',
#  'CHEMBL173202',
#  'CHEMBL2112951',
#  'CHEMBL369277',
#  'CHEMBL367988',
#  'CHEMBL173479',
#  'CHEMBL435347',
#  'CHEMBL433793',
#  'CHEMBL278085',
#  'CHEMBL176655',
#  'CHEMBL368204',
#  'CHEMBL20453',
#  'CHEMBL176850',
#  'CHEMBL369478',
#  'CHEMBL367169',
#  'CHEMBL368309',
#  'CHEMBL366770',
#  'CHEMBL283788',
#  'CHEMBL367461',
#  'CHEMBL176459',
#  'CHEMBL263529',
#  'CHEMBL172436',
#  'CHEMBL367246',
#  'CHEMBL367697',
#  'CHEMBL176337',
#  'CHEMBL369812',
#  'CHEMBL367987',
#  'CHEMBL353331',
#  'CHEMBL177205',
#  'CHEMBL368098',
#  'CHEMBL263787',
#  'CHEMBL173400',
#  'CHEMBL20622',
#  'CHEMBL170118',
#  'CHEMBL172004',
#  'CHEMBL176528',
#  'CHEMBL366871',
#  'CHEMBL172894',
#  'CHEMBL21058',
#  'CHEMBL280344',
#  'CHEMBL176859',
#  'CHEMBL368979',
#  'CHEMBL427122',
#  'CHEMBL174904',
#  'CHEMBL349974',
#  'CHEMBL174927',
#  'CHEMBL435472',
#  'CHEMBL278117',
#  'CHEMBL369151',
#  'CHEMBL170829',
#  'CHEMBL352511',
#  'CHEMBL173308',
#  'CHEMBL21106',
#  'CHEMBL174304',
#  'CHEMBL175424',
#  'CHEMBL265723',
#  'CHEMBL282921',
#  'CHEMBL417825',
#  'CHEMBL173492',
#  'CHEMBL367489',
#  'CHEMBL367529',
#  'CHEMBL368182',
#  'CHEMBL177157',
#  'CHEMBL369040',
#  'CHEMBL172013',
#  'CHEMBL177127',
#  'CHEMBL367560',
#  'CHEMBL20818',
#  'CHEMBL435538',
#  'CHEMBL367901',
#  'CHEMBL367916',
#  'CHEMBL369059',
#  'CHEMBL408800',
#  'CHEMBL20831',
#  'CHEMBL368459',
#  'CHEMBL367383',
#  'CHEMBL367700',
#  'CHEMBL177168',
#  'CHEMBL172916',
#  'CHEMBL176980',
#  'CHEMBL284010',
#  'CHEMBL353330',
#  'CHEMBL279992',
#  'CHEMBL20345',
#  'CHEMBL368332',
#  'CHEMBL2112952',
#  'CHEMBL366328',
#  'CHEMBL368375',
#  'CHEMBL366611',
#  'CHEMBL173482',
#  'CHEMBL369632',
#  'CHEMBL172322',
#  'CHEMBL281176',
#  'CHEMBL366610',
#  'CHEMBL368823',
#  'CHEMBL172079',
#  'CHEMBL172296',
#  'CHEMBL176426',
#  'CHEMBL174996',
#  'CHEMBL368467',
#  'CHEMBL367102',
#  'CHEMBL176571',
#  'CHEMBL369398',
#  'CHEMBL366492',
#  'CHEMBL175348',
#  'CHEMBL176669',
#  'CHEMBL366742',
#  'CHEMBL174004',
#  'CHEMBL368329',
#  'CHEMBL281607',
#  'CHEMBL171468',
#  'CHEMBL177204',
#  'CHEMBL173091',
#  'CHEMBL435554',
#  'CHEMBL366873',
#  'CHEMBL173019',
#  'CHEMBL20896',
#  'CHEMBL369822',
#  'CHEMBL427493',
#  'CHEMBL176624',
#  'CHEMBL369593',
#  'CHEMBL262663',
#  'CHEMBL175341',
#  'CHEMBL293882',
#  'CHEMBL65649',
#  'CHEMBL303964',
#  'CHEMBL62611',
#  'CHEMBL294788',
#  'CHEMBL62180',
#  'CHEMBL62549',
#  'CHEMBL62598',
#  'CHEMBL62454',
#  'CHEMBL292345',
#  'CHEMBL64322',
#  'CHEMBL61267',
#  'CHEMBL66301',
#  'CHEMBL293393',
#  'CHEMBL64591',
#  'CHEMBL56565',
#  'CHEMBL62339',
#  'CHEMBL61208',
#  'CHEMBL65696',
#  'CHEMBL64163',
#  'CHEMBL65681',
#  'CHEMBL41275',
#  'CHEMBL292548',
#  'CHEMBL65605',
#  'CHEMBL294501',
#  'CHEMBL138282',
#  'CHEMBL138282',
#  'CHEMBL79958',
#  'CHEMBL137524',
#  'CHEMBL137524',
#  'CHEMBL342842',
#  'CHEMBL342842',
#  'CHEMBL83311',
#  'CHEMBL137650',
#  'CHEMBL79369',
#  'CHEMBL137154',
#  'CHEMBL138437',
#  'CHEMBL138437',
#  'CHEMBL312808',
#  'CHEMBL136977',
#  'CHEMBL136977',
#  'CHEMBL83338',
#  'CHEMBL310305',
#  'CHEMBL83882',
#  'CHEMBL312231',
#  'CHEMBL137206',
#  'CHEMBL137206',
#  'CHEMBL137038',
#  'CHEMBL137038',
#  'CHEMBL79504',
#  'CHEMBL137728',
#  'CHEMBL137728',
#  'CHEMBL428104',
#  'CHEMBL428104',
#  'CHEMBL344261',
#  'CHEMBL344261',
#  'CHEMBL310780',
#  'CHEMBL431795',
#  'CHEMBL135432',
#  'CHEMBL135432',
#  'CHEMBL343366',
#  'CHEMBL343366',
#  'CHEMBL137327',
#  'CHEMBL137327',
#  'CHEMBL79697',
#  'CHEMBL82880',
#  'CHEMBL79882',
#  'CHEMBL82207',
#  'CHEMBL275998',
#  'CHEMBL275998',
#  'CHEMBL83107',
#  'CHEMBL83745',
#  'CHEMBL138645',
#  'CHEMBL138645',
#  'CHEMBL79566',
#  'CHEMBL343160',
#  'CHEMBL343160',
#  'CHEMBL344641',
#  'CHEMBL344641',
#  'CHEMBL335562',
#  'CHEMBL335562',
#  'CHEMBL137419',
#  'CHEMBL137419',
#  'CHEMBL137072',
#  'CHEMBL137072',
#  'CHEMBL84374',
#  'CHEMBL83818',
#  'CHEMBL137272',
#  'CHEMBL137272',
#  'CHEMBL83683',
#  'CHEMBL83963',
#  'CHEMBL82838',
#  'CHEMBL343745',
#  'CHEMBL343745',
#  'CHEMBL83957',
#  'CHEMBL81692',
#  'CHEMBL328297',
#  'CHEMBL312701',
#  'CHEMBL84120',
#  'CHEMBL79716',
#  'CHEMBL104698',
#  'CHEMBL319233',
#  'CHEMBL106381',
#  'CHEMBL105109',
#  'CHEMBL107128',
#  'CHEMBL106381',
#  'CHEMBL107749',
#  'CHEMBL317860',
#  'CHEMBL104793',
#  'CHEMBL79504',
#  'CHEMBL319697',
#  'CHEMBL314342',
#  'CHEMBL419172',
#  'CHEMBL105975',
#  'CHEMBL106907',
#  'CHEMBL83338',
#  'CHEMBL107439',
#  'CHEMBL41275',
#  'CHEMBL159097',
#  'CHEMBL157983',
#  'CHEMBL351973',
#  'CHEMBL157491',
#  'CHEMBL158754',
#  'CHEMBL539943',
#  'CHEMBL159018',
#  'CHEMBL436245',
#  'CHEMBL350027',
#  'CHEMBL161093',
#  'CHEMBL350763',
#  'CHEMBL161480',
#  'CHEMBL423427',
#  'CHEMBL158438',
#  'CHEMBL41275',
#  'CHEMBL161594',
#  'CHEMBL328260',
#  'CHEMBL435259',
#  'CHEMBL432010',
#  'CHEMBL330252',
#  'CHEMBL90927',
#  'CHEMBL326111',
#  'CHEMBL408438',
#  'CHEMBL89715',
#  'CHEMBL327880',
#  'CHEMBL328339',
#  'CHEMBL418954',
#  'CHEMBL328888',
#  'CHEMBL316189',
#  'CHEMBL313950',
#  'CHEMBL328898',
#  'CHEMBL107425',
#  'CHEMBL91413',
#  'CHEMBL92791',
#  'CHEMBL88219',
#  'CHEMBL312701',
#  'CHEMBL90841',
#  'CHEMBL105987',
#  'CHEMBL92147',
#  'CHEMBL312701',
#  'CHEMBL91522',
#  'CHEMBL88197',
#  'CHEMBL79716',
#  'CHEMBL83107',
#  'CHEMBL328908',
#  'CHEMBL329190',
#  'CHEMBL89958',
#  'CHEMBL89929',
#  'CHEMBL421598',
#  'CHEMBL316280',
#  'CHEMBL432040',
#  'CHEMBL79504',
#  'CHEMBL88455',
#  'CHEMBL106569',
#  'CHEMBL328438',
#  'CHEMBL91374',
#  'CHEMBL90747',
#  'CHEMBL88928',
#  'CHEMBL90152',
#  'CHEMBL88164',
#  'CHEMBL327846',
#  'CHEMBL321267',
#  'CHEMBL90291',
#  'CHEMBL90691',
#  'CHEMBL107170',
#  'CHEMBL317710',
#  'CHEMBL327484',
#  'CHEMBL421356',
#  'CHEMBL83338',
#  'CHEMBL420242',
#  'CHEMBL330486',
#  'CHEMBL328088',
#  'CHEMBL92094',
#  'CHEMBL104628',
#  'CHEMBL91387',
#  'CHEMBL420057',
#  'CHEMBL90141',
#  'CHEMBL88927',
#  'CHEMBL91892',
#  'CHEMBL89490',
#  'CHEMBL435886',
#  'CHEMBL371177',
#  'CHEMBL194497',
#  'CHEMBL250689',
#  'CHEMBL178189',
#  'CHEMBL426048',
#  'CHEMBL179141',
#  'CHEMBL179141',
#  'CHEMBL179209',
#  'CHEMBL179209',
#  'CHEMBL182188',
#  'CHEMBL361585',
#  'CHEMBL180274',
#  'CHEMBL85086',
#  'CHEMBL93139',
#  'CHEMBL359752',
#  'CHEMBL178319',
#  'CHEMBL178337',
#  'CHEMBL359687',
#  'CHEMBL360522',
#  'CHEMBL360667',
#  'CHEMBL362637',
#  'CHEMBL180013',
#  'CHEMBL182274',
#  'CHEMBL183769',
#  'CHEMBL180498',
#  'CHEMBL182682',
#  'CHEMBL182010',
#  'CHEMBL427144',
#  'CHEMBL180685',
#  'CHEMBL183554',
#  'CHEMBL179950',
#  'CHEMBL360524',
#  'CHEMBL182684',
#  'CHEMBL182878',
#  'CHEMBL180656',
#  'CHEMBL181913',
#  'CHEMBL179858',
#  'CHEMBL183409',
#  'CHEMBL182731',
#  'CHEMBL183709',
#  'CHEMBL360044',
#  'CHEMBL182817',
#  'CHEMBL182279',
#  'CHEMBL179877',
#  'CHEMBL179993',
#  'CHEMBL369311',
#  'CHEMBL360106',
#  'CHEMBL369352',
#  'CHEMBL182074',
#  'CHEMBL182929',
#  'CHEMBL182083',
#  'CHEMBL180155',
#  'CHEMBL426960',
#  'CHEMBL361444',
#  'CHEMBL425168',
#  'CHEMBL183710',
#  'CHEMBL183492',
#  'CHEMBL181967',
#  'CHEMBL178477',
#  'CHEMBL426250',
#  'CHEMBL183406',
#  'CHEMBL180184',
#  'CHEMBL183746',
#  'CHEMBL183261',
#  'CHEMBL183885',
#  'CHEMBL181858',
#  'CHEMBL182940',
#  'CHEMBL182780',
#  'CHEMBL182380',
#  'CHEMBL182266',
#  'CHEMBL183907',
#  'CHEMBL361414',
#  'CHEMBL181260',
#  'CHEMBL362388',
#  'CHEMBL181502',
#  'CHEMBL182234',
#  'CHEMBL427137',
#  'CHEMBL367586',
#  'CHEMBL367586',
#  'CHEMBL182403',
#  'CHEMBL362168',
#  'CHEMBL183553',
#  'CHEMBL180095',
#  'CHEMBL183293',
#  'CHEMBL360120',
#  'CHEMBL183875',
#  'CHEMBL182557',
#  'CHEMBL183514',
#  'CHEMBL180334',
#  'CHEMBL359986',
#  'CHEMBL359986',
#  'CHEMBL359986',
#  'CHEMBL366260',
#  'CHEMBL366260',
#  'CHEMBL366260',
#  'CHEMBL363999',
#  'CHEMBL363999',
#  'CHEMBL363999',
#  'CHEMBL193988',
#  'CHEMBL364070',
#  'CHEMBL191139',
#  'CHEMBL193972',
#  'CHEMBL193440',
#  'CHEMBL195199',
#  'CHEMBL436290',
#  'CHEMBL445925',
#  'CHEMBL196087',
#  'CHEMBL194078',
#  'CHEMBL192456',
#  'CHEMBL470512',
#  'CHEMBL2113086',
#  'CHEMBL191803',
#  'CHEMBL2113088',
#  'CHEMBL472798',
#  'CHEMBL475606',
#  'CHEMBL2113084',
#  'CHEMBL475777',
#  'CHEMBL472799',
#  'CHEMBL363564',
#  'CHEMBL193822',
#  'CHEMBL193984',
#  'CHEMBL363840',
#  'CHEMBL195753',
#  'CHEMBL195930',
#  'CHEMBL20896',
#  'CHEMBL195433',
#  'CHEMBL180155',
#  'CHEMBL182074',
#  'CHEMBL369311',
#  'CHEMBL199147',
#  'CHEMBL199258',
#  'CHEMBL198277',
#  'CHEMBL372852',
#  'CHEMBL197907',
#  'CHEMBL371865',
#  'CHEMBL197714',
#  'CHEMBL197641',
#  'CHEMBL197680',
#  'CHEMBL198777',
#  'CHEMBL198758',
#  'CHEMBL371691',
#  'CHEMBL372297',
#  'CHEMBL372134',
#  'CHEMBL198150',
#  'CHEMBL382079',
#  'CHEMBL369947',
#  'CHEMBL198497',
#  'CHEMBL199118',
#  'CHEMBL199119',
#  'CHEMBL370552',
#  'CHEMBL198114',
#  'CHEMBL198114',
#  'CHEMBL372733',
#  'CHEMBL198884',
#  'CHEMBL370998',
#  'CHEMBL2113131',
#  'CHEMBL372640',
#  'CHEMBL370826',
#  'CHEMBL373214',
#  'CHEMBL3085307',
#  'CHEMBL3085307',
#  'CHEMBL204821',
#  'CHEMBL41275',
#  'CHEMBL3085305',
#  'CHEMBL3085312',
#  'CHEMBL3085311',
#  'CHEMBL3085313',
#  'CHEMBL3085309',
#  'CHEMBL3085308',
#  'CHEMBL3085310',
#  'CHEMBL2105686',
#  'CHEMBL204821',
#  'CHEMBL41275',
#  'CHEMBL3085307',
#  'CHEMBL3085311',
#  'CHEMBL3085309',
#  'CHEMBL3085308',
#  'CHEMBL3085310',
#  'CHEMBL2105686',
#  'CHEMBL2105686',
#  'CHEMBL204821',
#  'CHEMBL3085311',
#  'CHEMBL3085309',
#  'CHEMBL3085308',
#  'CHEMBL207487',
#  'CHEMBL207004',
#  'CHEMBL377026',
#  'CHEMBL205706',
#  'CHEMBL205964',
#  'CHEMBL264832',
#  'CHEMBL206088',
#  'CHEMBL382252',
#  'CHEMBL207485',
#  'CHEMBL207633',
#  'CHEMBL207301',
#  'CHEMBL207630',
#  'CHEMBL210327',
#  'CHEMBL207447',
#  'CHEMBL205851',
#  'CHEMBL205539',
#  'CHEMBL207654',
#  'CHEMBL437494',
#  'CHEMBL207085',
#  'CHEMBL207182',
#  'CHEMBL207190',
#  'CHEMBL207487',
#  'CHEMBL207004',
#  'CHEMBL377026',
#  'CHEMBL205706',
#  'CHEMBL205964',
#  ...]

# %%
## 7.2. Iterando canonical smiles a uma lista
canonical_smiles = []
for i in df2.canonical_smiles:
    canonical_smiles.append(i)

# %%
## 7.3. Iterando para standard_value a uma lista
standard_value = []
for i in df2.standard_value:
    standard_value.append(i)

# %%
## 7.4. Combinando as quatro variáveis em um mesmo dataframe
dados_tupla = list(zip(mol_cid, canonical_smiles, classe_bioatividade, standard_value))
df3 = pd.DataFrame( dados_tupla,  columns=['molecule_chembl_id', 'canonical_smiles', 'classe_bioatividade', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL105460  C=CCN(C(=O)OCc1ccc([N+](=O)[O-])cc1)C1CCN(CCC(...
# 1          CHEMBL105606  C=CCN(C(=O)OCc1ccc([N+](=O)[O-])cc1)C1CCN(CCC(...
# 2          CHEMBL105570  C=CCN(C(=O)OCc1ccc([N+](=O)[O-])cc1)C1CCN(CCC(...
# 3           CHEMBL83338  CN(C[C@@H](CCN1CCC2(CC1)C[S+]([O-])c1ccccc12)c...
# 4          CHEMBL325357  C=CCN(C(=O)OCc1ccc([N+](=O)[O-])cc1)C1CCN(CCC(...
# ...                 ...                                                ...
# 2924      CHEMBL4594419  CC(=O)N[C@@H]1C[C@H](NC(C)(C)C)CC[C@@H]1N1CC[C...
# 2925      CHEMBL4781426  CC(=O)N[C@@H]1C[C@H](NC(C)(C)C)CC[C@@H]1N1CC[C...
# 2926      CHEMBL4594419  CC(=O)N[C@@H]1C[C@H](NC(C)(C)C)CC[C@@H]1N1CC[C...
# 2927      CHEMBL4781426  CC(=O)N[C@@H]1C[C@H](NC(C)(C)C)CC[C@@H]1N1CC[C...
# 2928      CHEMBL4594419  CC(=O)N[C@@H]1C[C@H](NC(C)(C)C)CC[C@@H]1N1CC[C...
#
#      classe_bioatividade standard_value
# 0                  Ativo          335.0
# 1                  Ativo           28.0
# 2                  Ativo           10.0
# 3                  Ativo           35.0
# 4                  Ativo           15.0
# ...                  ...            ...
# 2924               Ativo            3.6
# 2925               Ativo            1.1
# 2926               Ativo            1.1
# 2927               Ativo           34.7
# 2928               Ativo            5.7
#
# [2929 rows x 4 columns]

# %% [markdown]
# ## Passo 8: Salvar os dados pré-processados

# %%
# Salvando o dataframe para um ficheiro CSV

df3.to_csv('dados_preprocessados.csv', index=False)
